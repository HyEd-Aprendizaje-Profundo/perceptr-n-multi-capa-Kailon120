# %% [markdown]
# # Práctica 1: Perceptrón multicapa.
#
# Tu jefe pidió a RH que recolectara datos de desempeño de tus compañeros, los resultados se almacenaron en un csv. El punto critico de estos datos es la satisfacción del empleado, entonces ¿Podremos estimar la satisfacción de los empleados con los datos recabados?.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
import numpy as np
from tensorflow.keras import layers, models


df = pd.read_csv('Extended_Employee_Performance_and_Productivity_Data.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Employee_ID                  100000 non-null  int64
#  1   Department                   100000 non-null  object
#  2   Gender                       100000 non-null  object
#  3   Age                          100000 non-null  int64
#  4   Job_Title                    100000 non-null  object
#  5   Hire_Date                    100000 non-null  object
#  6   Years_At_Company             100000 non-null  int64
#  7   Education_Level              100000 non-null  object
#  8   Performance_Score            100000 non-null  int64
#  9   Monthly_Salary               100000 non-null  float64
#  10  Work_Hours_Per_Week          100000 non-null  int64
#  11  Projects_Handled             100000 non-null  int64
#  12  Overtime_Hours               100000 non-null  int64
#  13  Sick_Days                    100000 non-null  int64
#  14  Remote_Work_Frequency        100000 non-null  int64
#  15  Team_Size                    100000 non-null  int64
#  16  Training_Hours               100000 non-null  int64
#  17  Promotions                   100000 non-null  int64
#  18  Employee_Satisfaction_Score  100000 non-null  float64
#  19  Resigned                     100000 non-null  bool
# dtypes: bool(1), float64(2), int64(12), object(5)
# memory usage: 14.6+ MB

# %%
# Filtrar las columnas numéricas
numeric_columns = df.select_dtypes(include=['number']).drop('Employee_ID',axis=1)


# Si numeric_columns es un Index, conviértelo a lista
cols = list(numeric_columns)

fig, axes = plt.subplots(1, len(cols), figsize=(5 * len(cols), 4))

for i, col in enumerate(cols):
    axes[i].hist(df[col], bins=20, color='skyblue', edgecolor='black')
    axes[i].set_title(col)
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Frecuencia')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Problemas**, tenemos distribuciones con picos, esos nos indica categorías. Por otro lado, tenemos variables con "valles" en su distribución (distribuciones multimodales) por lo que resultaría óptimo aplicar técnicas de feature engeneering. Por último tenemos distribuciones uniformes, por lo que cada una requeriría un procesamiento indivudual, hagamos la vista gorda e intentemos ajustar un MLP con estos datos, solo estandaricemos nuestros datos.

# %% [markdown]
# ---
#
# ## Implementación de Red:
#
# Tomemos los datos numéricos como nuestra variable X, y la variable objetivo como ***'Employee_Satisfaction_Score'***.
# - **Actividad 1**: Para todos los strings ``'@modif@'`` que aparescan en el siguiente bloque de código cámbialos para que el código funcione.

# %%
X = numeric_columns.drop('Employee_Satisfaction_Score',axis = 1)
y = numeric_columns['Employee_Satisfaction_Score']
y = y.apply(lambda x: round(x)-1) #Cambiamos la variable objetivo a 5 categorías numéricas

scaler = StandardScaler()
X_standar = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_standar, y, test_size=0.33, random_state=42)

y_onehot_train = tf.keras.utils.to_categorical(y_train, 5)
y_onehot_test = tf.keras.utils.to_categorical(y_test,5)

# %% [markdown]
# - **Actividad 2:** Implementa 3 arquitecturas de MLP, cada una con su propio nombre, cambiando la estructura de dichas arquitecturas (capas, neuronas por capa, función de activación, etc).

# %%
# Modelo 1 - SimpleMLP
SimpleMLP = models.Sequential(name="SimpleMLP")
SimpleMLP.add(layers.Input(shape=(X_train.shape[1],)))  # Capa de entrada
SimpleMLP.add(layers.Dense(32, activation='relu'))
SimpleMLP.add(layers.Dense(16, activation='relu'))
SimpleMLP.add(layers.Dense(5, activation='softmax'))  # 5 clases

# %%
# Modelo 2 - DeepMLP (más capas y dropout)
DeepMLP = models.Sequential(name="DeepMLP")
DeepMLP.add(layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)))
DeepMLP.add(layers.Dropout(0.3))
DeepMLP.add(layers.Dense(32, activation='relu'))
DeepMLP.add(layers.Dropout(0.3))
DeepMLP.add(layers.Dense(16, activation='relu'))
DeepMLP.add(layers.Dense(5, activation='softmax'))

# %%
# Modelo 3 - WideMLP (menos capas pero muchas neuronas)
WideMLP = models.Sequential(name="WideMLP")
WideMLP.add(layers.Dense(128, activation='tanh', input_shape=(X_train.shape[1],)))
WideMLP.add(layers.Dense(64, activation='tanh'))
WideMLP.add(layers.Dense(5, activation='softmax'))

# %% [markdown]
# - **Actividad 3:** Compila y ajusta tus tres modelos con sus respectivos hiperparámetros.

# %%
# Modelo 1
SimpleMLP.compile(optimizer='adam', 
                  loss='categorical_crossentropy', 
                  metrics=['accuracy'])

hist1 = SimpleMLP.fit(X_train, y_onehot_train, 
                      validation_data=(X_test, y_onehot_test),
                      epochs=50, batch_size=16, verbose=1)
# Out:
# Epoch 1/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 4s 834us/step - accuracy: 0.2542 - loss: 1.5617 - val_accuracy: 0.2526 - val_loss: 1.5588
# Epoch 2/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 759us/step - accuracy: 0.2570 - loss: 1.5563 - val_accuracy: 0.2560 - val_loss: 1.5581
# Epoch 3/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 779us/step - accuracy: 0.2599 - loss: 1.5552 - val_accuracy: 0.2527 - val_loss: 1.5579
# Epoch 4/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 794us/step - accuracy: 0.2624 - loss: 1.5547 - val_accuracy: 0.2509 - val_loss: 1.5579
# Epoch 5/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 780us/step - accuracy: 0.2660 - loss: 1.5543 - val_accuracy: 0.2522 - val_loss: 1.5581
# Epoch 6/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 805us/step - accuracy: 0.2671 - loss: 1.5536 - val_accuracy: 0.2526 - val_loss: 1.5580
# Epoch 7/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 4s 851us/step - accuracy: 0.2680 - loss: 1.5533 - val_accuracy: 0.2538 - val_loss: 1.5594
# Epoch 8/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 803us/step - accuracy: 0.2695 - loss: 1.5530 - val_accuracy: 0.2516 - val_loss: 1.5590
# Epoch 9/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 793us/step - accuracy: 0.2697 - loss: 1.5527 - val_accuracy: 0.2537 - val_loss: 1.5604
# Epoch 10/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 812us/step - accuracy: 0.2684 - loss: 1.5523 - val_accuracy: 0.2536 - val_loss: 1.5592
# Epoch 11/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 783us/step - accuracy: 0.2692 - loss: 1.5520 - val_accuracy: 0.2505 - val_loss: 1.5593
# Epoch 12/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 787us/step - accuracy: 0.2712 - loss: 1.5519 - val_accuracy: 0.2553 - val_loss: 1.5601
# Epoch 13/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 814us/step - accuracy: 0.2712 - loss: 1.5514 - val_accuracy: 0.2512 - val_loss: 1.5603
# Epoch 14/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 818us/step - accuracy: 0.2759 - loss: 1.5510 - val_accuracy: 0.2554 - val_loss: 1.5605
# Epoch 15/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 5s 785us/step - accuracy: 0.2751 - loss: 1.5506 - val_accuracy: 0.2538 - val_loss: 1.5598
# Epoch 16/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 779us/step - accuracy: 0.2744 - loss: 1.5505 - val_accuracy: 0.2554 - val_loss: 1.5602
# Epoch 17/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 793us/step - accuracy: 0.2747 - loss: 1.5504 - val_accuracy: 0.2549 - val_loss: 1.5616
# Epoch 18/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 794us/step - accuracy: 0.2736 - loss: 1.5503 - val_accuracy: 0.2540 - val_loss: 1.5610
# Epoch 19/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 795us/step - accuracy: 0.2756 - loss: 1.5496 - val_accuracy: 0.2546 - val_loss: 1.5620
# Epoch 20/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 781us/step - accuracy: 0.2765 - loss: 1.5493 - val_accuracy: 0.2550 - val_loss: 1.5623
# Epoch 21/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 766us/step - accuracy: 0.2784 - loss: 1.5490 - val_accuracy: 0.2544 - val_loss: 1.5626
# Epoch 22/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 791us/step - accuracy: 0.2780 - loss: 1.5487 - val_accuracy: 0.2554 - val_loss: 1.5628
# Epoch 23/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 778us/step - accuracy: 0.2775 - loss: 1.5487 - val_accuracy: 0.2525 - val_loss: 1.5626
# Epoch 24/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 777us/step - accuracy: 0.2777 - loss: 1.5485 - val_accuracy: 0.2550 - val_loss: 1.5632
# Epoch 25/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 776us/step - accuracy: 0.2782 - loss: 1.5481 - val_accuracy: 0.2535 - val_loss: 1.5634
# Epoch 26/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 805us/step - accuracy: 0.2778 - loss: 1.5478 - val_accuracy: 0.2568 - val_loss: 1.5629
# Epoch 27/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 805us/step - accuracy: 0.2785 - loss: 1.5478 - val_accuracy: 0.2538 - val_loss: 1.5644
# Epoch 28/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 794us/step - accuracy: 0.2817 - loss: 1.5473 - val_accuracy: 0.2567 - val_loss: 1.5643
# Epoch 29/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 782us/step - accuracy: 0.2792 - loss: 1.5474 - val_accuracy: 0.2555 - val_loss: 1.5637
# Epoch 30/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 778us/step - accuracy: 0.2805 - loss: 1.5471 - val_accuracy: 0.2562 - val_loss: 1.5653
# Epoch 31/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 794us/step - accuracy: 0.2788 - loss: 1.5470 - val_accuracy: 0.2542 - val_loss: 1.5639
# Epoch 32/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 792us/step - accuracy: 0.2791 - loss: 1.5464 - val_accuracy: 0.2554 - val_loss: 1.5650
# Epoch 33/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 808us/step - accuracy: 0.2801 - loss: 1.5466 - val_accuracy: 0.2548 - val_loss: 1.5640
# Epoch 34/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 789us/step - accuracy: 0.2792 - loss: 1.5465 - val_accuracy: 0.2535 - val_loss: 1.5648
# Epoch 35/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 787us/step - accuracy: 0.2788 - loss: 1.5463 - val_accuracy: 0.2558 - val_loss: 1.5658
# Epoch 36/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 786us/step - accuracy: 0.2821 - loss: 1.5458 - val_accuracy: 0.2558 - val_loss: 1.5663
# Epoch 37/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 802us/step - accuracy: 0.2814 - loss: 1.5460 - val_accuracy: 0.2554 - val_loss: 1.5653
# Epoch 38/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 787us/step - accuracy: 0.2818 - loss: 1.5458 - val_accuracy: 0.2554 - val_loss: 1.5657
# Epoch 39/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 792us/step - accuracy: 0.2814 - loss: 1.5456 - val_accuracy: 0.2569 - val_loss: 1.5652
# Epoch 40/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 784us/step - accuracy: 0.2806 - loss: 1.5458 - val_accuracy: 0.2557 - val_loss: 1.5659
# Epoch 41/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 797us/step - accuracy: 0.2818 - loss: 1.5454 - val_accuracy: 0.2576 - val_loss: 1.5665
# Epoch 42/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 808us/step - accuracy: 0.2827 - loss: 1.5453 - val_accuracy: 0.2538 - val_loss: 1.5660
# Epoch 43/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 803us/step - accuracy: 0.2820 - loss: 1.5452 - val_accuracy: 0.2555 - val_loss: 1.5670
# Epoch 44/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 798us/step - accuracy: 0.2830 - loss: 1.5449 - val_accuracy: 0.2543 - val_loss: 1.5665
# Epoch 45/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 811us/step - accuracy: 0.2840 - loss: 1.5449 - val_accuracy: 0.2539 - val_loss: 1.5680
# Epoch 46/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 828us/step - accuracy: 0.2836 - loss: 1.5447 - val_accuracy: 0.2557 - val_loss: 1.5670
# Epoch 47/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 826us/step - accuracy: 0.2844 - loss: 1.5448 - val_accuracy: 0.2536 - val_loss: 1.5665
# Epoch 48/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 4s 837us/step - accuracy: 0.2844 - loss: 1.5448 - val_accuracy: 0.2523 - val_loss: 1.5665
# Epoch 49/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 810us/step - accuracy: 0.2853 - loss: 1.5444 - val_accuracy: 0.2545 - val_loss: 1.5692
# Epoch 50/50
# 4188/4188 ━━━━━━━━━━━━━━━━━━━━ 3s 808us/step - accuracy: 0.2833 - loss: 1.5444 - val_accuracy: 0.2551 - val_loss: 1.5679

# %%
# Modelo 2
DeepMLP.compile(optimizer='adam', 
                loss='categorical_crossentropy', 
                metrics=['accuracy'])

hist2 = DeepMLP.fit(X_train, y_onehot_train, 
                    validation_data=(X_test, y_onehot_test),
                    epochs=50, batch_size=32, verbose=1)
# Out:
# Epoch 1/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 3s 936us/step - accuracy: 0.2520 - loss: 1.5635 - val_accuracy: 0.2556 - val_loss: 1.5575
# Epoch 2/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 853us/step - accuracy: 0.2529 - loss: 1.5560 - val_accuracy: 0.2506 - val_loss: 1.5578
# Epoch 3/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 864us/step - accuracy: 0.2525 - loss: 1.5556 - val_accuracy: 0.2525 - val_loss: 1.5569
# Epoch 4/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 849us/step - accuracy: 0.2506 - loss: 1.5554 - val_accuracy: 0.2542 - val_loss: 1.5570
# Epoch 5/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 851us/step - accuracy: 0.2552 - loss: 1.5552 - val_accuracy: 0.2504 - val_loss: 1.5572
# Epoch 6/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 840us/step - accuracy: 0.2552 - loss: 1.5552 - val_accuracy: 0.2518 - val_loss: 1.5569
# Epoch 7/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 890us/step - accuracy: 0.2535 - loss: 1.5552 - val_accuracy: 0.2534 - val_loss: 1.5575
# Epoch 8/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 859us/step - accuracy: 0.2519 - loss: 1.5552 - val_accuracy: 0.2532 - val_loss: 1.5571
# Epoch 9/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 889us/step - accuracy: 0.2526 - loss: 1.5551 - val_accuracy: 0.2515 - val_loss: 1.5570
# Epoch 10/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 853us/step - accuracy: 0.2520 - loss: 1.5550 - val_accuracy: 0.2525 - val_loss: 1.5570
# Epoch 11/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 893us/step - accuracy: 0.2539 - loss: 1.5550 - val_accuracy: 0.2508 - val_loss: 1.5572
# Epoch 12/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 872us/step - accuracy: 0.2547 - loss: 1.5550 - val_accuracy: 0.2532 - val_loss: 1.5570
# Epoch 13/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 862us/step - accuracy: 0.2546 - loss: 1.5549 - val_accuracy: 0.2508 - val_loss: 1.5576
# Epoch 14/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 918us/step - accuracy: 0.2563 - loss: 1.5549 - val_accuracy: 0.2527 - val_loss: 1.5570
# Epoch 15/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 884us/step - accuracy: 0.2545 - loss: 1.5550 - val_accuracy: 0.2519 - val_loss: 1.5570
# Epoch 16/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 908us/step - accuracy: 0.2572 - loss: 1.5547 - val_accuracy: 0.2521 - val_loss: 1.5569
# Epoch 17/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 894us/step - accuracy: 0.2555 - loss: 1.5547 - val_accuracy: 0.2533 - val_loss: 1.5569
# Epoch 18/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 907us/step - accuracy: 0.2573 - loss: 1.5546 - val_accuracy: 0.2514 - val_loss: 1.5574
# Epoch 19/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 910us/step - accuracy: 0.2579 - loss: 1.5545 - val_accuracy: 0.2546 - val_loss: 1.5571
# Epoch 20/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 848us/step - accuracy: 0.2586 - loss: 1.5544 - val_accuracy: 0.2552 - val_loss: 1.5569
# Epoch 21/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 903us/step - accuracy: 0.2570 - loss: 1.5544 - val_accuracy: 0.2528 - val_loss: 1.5570
# Epoch 22/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 900us/step - accuracy: 0.2587 - loss: 1.5545 - val_accuracy: 0.2541 - val_loss: 1.5570
# Epoch 23/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 864us/step - accuracy: 0.2590 - loss: 1.5543 - val_accuracy: 0.2526 - val_loss: 1.5570
# Epoch 24/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 909us/step - accuracy: 0.2598 - loss: 1.5543 - val_accuracy: 0.2540 - val_loss: 1.5572
# Epoch 25/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 889us/step - accuracy: 0.2589 - loss: 1.5543 - val_accuracy: 0.2539 - val_loss: 1.5572
# Epoch 26/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 900us/step - accuracy: 0.2583 - loss: 1.5544 - val_accuracy: 0.2554 - val_loss: 1.5569
# Epoch 27/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 904us/step - accuracy: 0.2597 - loss: 1.5540 - val_accuracy: 0.2540 - val_loss: 1.5571
# Epoch 28/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 861us/step - accuracy: 0.2607 - loss: 1.5542 - val_accuracy: 0.2537 - val_loss: 1.5573
# Epoch 29/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 3s 868us/step - accuracy: 0.2599 - loss: 1.5541 - val_accuracy: 0.2487 - val_loss: 1.5575
# Epoch 30/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 917us/step - accuracy: 0.2578 - loss: 1.5538 - val_accuracy: 0.2526 - val_loss: 1.5576
# Epoch 31/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 866us/step - accuracy: 0.2609 - loss: 1.5542 - val_accuracy: 0.2529 - val_loss: 1.5574
# Epoch 32/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 905us/step - accuracy: 0.2600 - loss: 1.5538 - val_accuracy: 0.2513 - val_loss: 1.5575
# Epoch 33/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 894us/step - accuracy: 0.2619 - loss: 1.5537 - val_accuracy: 0.2526 - val_loss: 1.5573
# Epoch 34/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 911us/step - accuracy: 0.2602 - loss: 1.5539 - val_accuracy: 0.2515 - val_loss: 1.5572
# Epoch 35/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 914us/step - accuracy: 0.2605 - loss: 1.5535 - val_accuracy: 0.2526 - val_loss: 1.5574
# Epoch 36/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 882us/step - accuracy: 0.2626 - loss: 1.5534 - val_accuracy: 0.2512 - val_loss: 1.5576
# Epoch 37/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 902us/step - accuracy: 0.2621 - loss: 1.5536 - val_accuracy: 0.2512 - val_loss: 1.5575
# Epoch 38/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 864us/step - accuracy: 0.2619 - loss: 1.5533 - val_accuracy: 0.2521 - val_loss: 1.5578
# Epoch 39/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 913us/step - accuracy: 0.2627 - loss: 1.5532 - val_accuracy: 0.2546 - val_loss: 1.5578
# Epoch 40/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 916us/step - accuracy: 0.2638 - loss: 1.5531 - val_accuracy: 0.2525 - val_loss: 1.5578
# Epoch 41/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 882us/step - accuracy: 0.2613 - loss: 1.5531 - val_accuracy: 0.2514 - val_loss: 1.5573
# Epoch 42/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 910us/step - accuracy: 0.2634 - loss: 1.5530 - val_accuracy: 0.2515 - val_loss: 1.5575
# Epoch 43/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 886us/step - accuracy: 0.2627 - loss: 1.5531 - val_accuracy: 0.2532 - val_loss: 1.5574
# Epoch 44/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 894us/step - accuracy: 0.2648 - loss: 1.5530 - val_accuracy: 0.2532 - val_loss: 1.5575
# Epoch 45/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 926us/step - accuracy: 0.2626 - loss: 1.5532 - val_accuracy: 0.2533 - val_loss: 1.5575
# Epoch 46/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 892us/step - accuracy: 0.2648 - loss: 1.5526 - val_accuracy: 0.2508 - val_loss: 1.5578
# Epoch 47/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 901us/step - accuracy: 0.2644 - loss: 1.5528 - val_accuracy: 0.2516 - val_loss: 1.5577
# Epoch 48/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 903us/step - accuracy: 0.2618 - loss: 1.5533 - val_accuracy: 0.2518 - val_loss: 1.5575
# Epoch 49/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 920us/step - accuracy: 0.2662 - loss: 1.5529 - val_accuracy: 0.2538 - val_loss: 1.5575
# Epoch 50/50
# 2094/2094 ━━━━━━━━━━━━━━━━━━━━ 2s 911us/step - accuracy: 0.2643 - loss: 1.5525 - val_accuracy: 0.2496 - val_loss: 1.5578

# %%
# Modelo 3
WideMLP.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.005),
                loss='categorical_crossentropy', 
                metrics=['accuracy'])

hist3 = WideMLP.fit(X_train, y_onehot_train, 
                    validation_data=(X_test, y_onehot_test),
                    epochs=50, batch_size=64, verbose=1)
# Out:
# Epoch 1/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2518 - loss: 1.5684 - val_accuracy: 0.2549 - val_loss: 1.5599
# Epoch 2/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 922us/step - accuracy: 0.2526 - loss: 1.5580 - val_accuracy: 0.2505 - val_loss: 1.5598
# Epoch 3/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 859us/step - accuracy: 0.2539 - loss: 1.5573 - val_accuracy: 0.2526 - val_loss: 1.5609
# Epoch 4/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 880us/step - accuracy: 0.2508 - loss: 1.5574 - val_accuracy: 0.2539 - val_loss: 1.5589
# Epoch 5/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 843us/step - accuracy: 0.2497 - loss: 1.5572 - val_accuracy: 0.2514 - val_loss: 1.5576
# Epoch 6/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 905us/step - accuracy: 0.2533 - loss: 1.5581 - val_accuracy: 0.2486 - val_loss: 1.5609
# Epoch 7/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 866us/step - accuracy: 0.2524 - loss: 1.5575 - val_accuracy: 0.2488 - val_loss: 1.5595
# Epoch 8/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 844us/step - accuracy: 0.2497 - loss: 1.5578 - val_accuracy: 0.2518 - val_loss: 1.5573
# Epoch 9/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 865us/step - accuracy: 0.2543 - loss: 1.5577 - val_accuracy: 0.2521 - val_loss: 1.5582
# Epoch 10/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 893us/step - accuracy: 0.2546 - loss: 1.5579 - val_accuracy: 0.2485 - val_loss: 1.5580
# Epoch 11/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 859us/step - accuracy: 0.2500 - loss: 1.5577 - val_accuracy: 0.2491 - val_loss: 1.5579
# Epoch 12/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 913us/step - accuracy: 0.2527 - loss: 1.5578 - val_accuracy: 0.2525 - val_loss: 1.5622
# Epoch 13/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 895us/step - accuracy: 0.2540 - loss: 1.5579 - val_accuracy: 0.2510 - val_loss: 1.5583
# Epoch 14/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 866us/step - accuracy: 0.2542 - loss: 1.5576 - val_accuracy: 0.2511 - val_loss: 1.5581
# Epoch 15/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 891us/step - accuracy: 0.2537 - loss: 1.5578 - val_accuracy: 0.2532 - val_loss: 1.5588
# Epoch 16/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 862us/step - accuracy: 0.2521 - loss: 1.5577 - val_accuracy: 0.2550 - val_loss: 1.5582
# Epoch 17/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 869us/step - accuracy: 0.2502 - loss: 1.5578 - val_accuracy: 0.2481 - val_loss: 1.5629
# Epoch 18/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 931us/step - accuracy: 0.2506 - loss: 1.5582 - val_accuracy: 0.2527 - val_loss: 1.5604
# Epoch 19/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 881us/step - accuracy: 0.2529 - loss: 1.5571 - val_accuracy: 0.2514 - val_loss: 1.5597
# Epoch 20/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 885us/step - accuracy: 0.2518 - loss: 1.5579 - val_accuracy: 0.2537 - val_loss: 1.5598
# Epoch 21/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 870us/step - accuracy: 0.2531 - loss: 1.5580 - val_accuracy: 0.2515 - val_loss: 1.5584
# Epoch 22/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 939us/step - accuracy: 0.2519 - loss: 1.5574 - val_accuracy: 0.2517 - val_loss: 1.5659
# Epoch 23/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 871us/step - accuracy: 0.2520 - loss: 1.5579 - val_accuracy: 0.2508 - val_loss: 1.5572
# Epoch 24/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2523 - loss: 1.5578 - val_accuracy: 0.2525 - val_loss: 1.5577
# Epoch 25/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2546 - loss: 1.5578 - val_accuracy: 0.2541 - val_loss: 1.5575
# Epoch 26/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2521 - loss: 1.5580 - val_accuracy: 0.2509 - val_loss: 1.5585
# Epoch 27/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2540 - loss: 1.5576 - val_accuracy: 0.2527 - val_loss: 1.5587
# Epoch 28/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2517 - loss: 1.5580 - val_accuracy: 0.2485 - val_loss: 1.5589
# Epoch 29/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2516 - loss: 1.5575 - val_accuracy: 0.2510 - val_loss: 1.5585
# Epoch 30/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2517 - loss: 1.5577 - val_accuracy: 0.2529 - val_loss: 1.5579
# Epoch 31/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2559 - loss: 1.5584 - val_accuracy: 0.2480 - val_loss: 1.5609
# Epoch 32/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2528 - loss: 1.5576 - val_accuracy: 0.2519 - val_loss: 1.5582
# Epoch 33/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2523 - loss: 1.5580 - val_accuracy: 0.2502 - val_loss: 1.5585
# Epoch 34/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 993us/step - accuracy: 0.2514 - loss: 1.5576 - val_accuracy: 0.2503 - val_loss: 1.5575
# Epoch 35/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2521 - loss: 1.5573 - val_accuracy: 0.2531 - val_loss: 1.5582
# Epoch 36/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2535 - loss: 1.5584 - val_accuracy: 0.2462 - val_loss: 1.5602
# Epoch 37/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2514 - loss: 1.5574 - val_accuracy: 0.2522 - val_loss: 1.5626
# Epoch 38/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2538 - loss: 1.5580 - val_accuracy: 0.2508 - val_loss: 1.5601
# Epoch 39/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.2522 - loss: 1.5579 - val_accuracy: 0.2542 - val_loss: 1.5580
# Epoch 40/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2505 - loss: 1.5579 - val_accuracy: 0.2496 - val_loss: 1.5656
# Epoch 41/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.2523 - loss: 1.5580 - val_accuracy: 0.2527 - val_loss: 1.5582
# Epoch 42/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2541 - loss: 1.5584 - val_accuracy: 0.2515 - val_loss: 1.5584
# Epoch 43/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2524 - loss: 1.5575 - val_accuracy: 0.2486 - val_loss: 1.5582
# Epoch 44/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2528 - loss: 1.5575 - val_accuracy: 0.2492 - val_loss: 1.5573
# Epoch 45/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2519 - loss: 1.5576 - val_accuracy: 0.2493 - val_loss: 1.5622
# Epoch 46/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2542 - loss: 1.5577 - val_accuracy: 0.2522 - val_loss: 1.5584
# Epoch 47/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.2535 - loss: 1.5577 - val_accuracy: 0.2520 - val_loss: 1.5594
# Epoch 48/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2534 - loss: 1.5580 - val_accuracy: 0.2536 - val_loss: 1.5576
# Epoch 49/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.2489 - loss: 1.5577 - val_accuracy: 0.2518 - val_loss: 1.5579
# Epoch 50/50
# 1047/1047 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.2566 - loss: 1.5578 - val_accuracy: 0.2562 - val_loss: 1.5580

# %% [markdown]
# - **Actividad 4:** Sube tus cambios al repositorio, envía el link de tu repositorio a la actividad 2 de tu checkpoint 2 y contesta las preguntas de dicha actividad.

# %%
import matplotlib.pyplot as plt

# Función para graficar accuracy y pérdida
def graficar_historial(hist, nombre):
    fig, axs = plt.subplots(1, 2, figsize=(12, 4))
    
    # Accuracy
    axs[0].plot(hist.history['accuracy'], label='Entrenamiento')
    axs[0].plot(hist.history['val_accuracy'], label='Validación')
    axs[0].set_title(f'Precisión - {nombre}')
    axs[0].set_xlabel('Épocas')
    axs[0].set_ylabel('Accuracy')
    axs[0].legend()

    # Pérdida
    axs[1].plot(hist.history['loss'], label='Entrenamiento')
    axs[1].plot(hist.history['val_loss'], label='Validación')
    axs[1].set_title(f'Pérdida - {nombre}')
    axs[1].set_xlabel('Épocas')
    axs[1].set_ylabel('Loss')
    axs[1].legend()

    plt.show()

# Graficar cada modelo
graficar_historial(hist1, "SimpleMLP")
graficar_historial(hist2, "DeepMLP")
graficar_historial(hist3, "WideMLP")
